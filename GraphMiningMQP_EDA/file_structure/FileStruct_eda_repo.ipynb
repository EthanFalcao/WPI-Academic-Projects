# %%
# Import the libraries
import os
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#topStared=pd.read_csv('data/TopStaredRepositories.csv', sep=",")
#commits=pd.read_csv('data/commitsTopStaredRepositories.csv', sep=",")
#flask=pd.read_csv('data/pallets_flask.csv', sep=",")

# %% [markdown]
# ## Data Info

# %%
#parse throught folder with csv and put into a df
import os
import pandas as pd

#  folder path containing CSV files
folder_path = '../../data(too large)/repoFileStructures'




df = pd.DataFrame()

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)

        try:
            current_df = pd.read_csv(file_path, on_bad_lines='skip')
            df = pd.concat([df, current_df], ignore_index=True)
        except pd.errors.ParserError as e:
            print(f"Error reading {filename}: {e}")
            
            
df = df.rename(columns={'fileTuple<name.size>': 'name-size'})

# %% [markdown]
# ### Split data

# %%
df[['filePath', 'fileSize','idk',"test"]] = df['name-size'].str.strip("()").str.split(', ', expand=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2258523 entries, 0 to 2258522
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   owner      object
#  1   repo       object
#  2   name-size  object
#  3   filePath   object
#  4   fileSize   object
#  5   idk        object
#  6   test       object
# dtypes: object(7)
# memory usage: 120.6+ MB

# %%
df['owner'].value_counts().head()
# Out:
# owner
# facebook               155100
# servo                  127066
# Alexander-MacDonald    100005
# elastic                 99928
# torvalds                82439
# Name: count, dtype: int64

# %%
df['repo'].value_counts().head()
# Out:
# repo
# servo        127066
# test-repo    100005
# hhvm          89616
# linux         82439
# kotlin        82251
# Name: count, dtype: int64

# %%
print("Unique Owner:", df['owner'].nunique())
print("Unique Repo:",  df['repo'].nunique())
# Out:
# Unique Owner: 809
# Unique Repo: 955

# %% [markdown]
# ## Data Cleaning

# %%
not_null_rows = df[df['idk'].notna()]

# Display the DataFrame with non-null rows
print(not_null_rows)
# Out:
#              owner        repo  \
# 190650      apache       spark
# 190651      apache       spark
# 527276      dotnet      roslyn
# 527277      dotnet      roslyn
# 1302123  Microsoft        CNTK
# 1306193  Microsoft  TypeScript
# 1313898  Microsoft  TypeScript
# 1313899  Microsoft  TypeScript
# 1313936  Microsoft  TypeScript
# 1313937  Microsoft  TypeScript
# 1313938  Microsoft  TypeScript
# 1313939  Microsoft  TypeScript
# 1313940  Microsoft  TypeScript
# 1313941  Microsoft  TypeScript
# 1313942  Microsoft  TypeScript
# 1313943  Microsoft  TypeScript
# 1313944  Microsoft  TypeScript
# 1313945  Microsoft  TypeScript
# 1313946  Microsoft  TypeScript
# 1313947  Microsoft  TypeScript
# 1585162    OpenEmu     OpenEmu
# 1585621    OpenEmu     OpenEmu
# 1766526       ruby        ruby
# 1766527       ruby        ruby
# 1766528       ruby        ruby
# 2233094       xitu  gold-miner
#
#                                                  name-size  \
# 190650   ('main/sql/hive/src/test/resources/golden/Part...
# 190651   ('main/sql/hive/src/test/resources/golden/Part...
# 527276   ('main/docs/contributing/Building, Debugging, ...
# 527277   ('main/docs/contributing/Building, Debugging, ...
# 1302123  ('main/Source/CNTK/BrainScript/Doc/BrainScript...
# 1306193  ('main/tests/baselines/reference/JSDocParsing/...
# 1313898  ('main/tests/baselines/reference/config/matchF...
# 1313899  ('main/tests/baselines/reference/config/matchF...
# 1313936  ('main/tests/baselines/reference/config/matchF...
# 1313937  ('main/tests/baselines/reference/config/matchF...
# 1313938  ('main/tests/baselines/reference/config/matchF...
# 1313939  ('main/tests/baselines/reference/config/matchF...
# 1313940  ('main/tests/baselines/reference/config/matchF...
# 1313941  ('main/tests/baselines/reference/config/matchF...
# 1313942  ('main/tests/baselines/reference/config/matchF...
# 1313943  ('main/tests/baselines/reference/config/matchF...
# 1313944  ('main/tests/baselines/reference/config/matchF...
# 1313945  ('main/tests/baselines/reference/config/matchF...
# 1313946  ('main/tests/baselines/reference/config/matchF...
# 1313947  ('main/tests/baselines/reference/config/matchF...
# 1585162  ('main/OpenEmu.xcworkspace/xcshareddata/xcsche...
# 1585621  ('main/OpenEmu/OpenEmu.xcodeproj/xcshareddata/...
# 1766526  ('main/test/rdoc/MarkdownTest_1.0.3/Links, inl...
# 1766527  ('main/test/rdoc/MarkdownTest_1.0.3/Links, ref...
# 1766528  ('main/test/rdoc/MarkdownTest_1.0.3/Links, sho...
# 2233094  ('main/TODO/Of SVG, Minification and Gzip', 12...
#
#                                                   filePath  \
# 190650   'main/sql/hive/src/test/resources/golden/Parti...
# 190651   'main/sql/hive/src/test/resources/golden/Parti...
# 527276                    'main/docs/contributing/Building
# 527277                    'main/docs/contributing/Building
# 1302123  'main/Source/CNTK/BrainScript/Doc/BrainScript-...
# 1306193  'main/tests/baselines/reference/JSDocParsing/D...
# 1313898  'main/tests/baselines/reference/config/matchFi...
# 1313899  'main/tests/baselines/reference/config/matchFi...
# 1313936  'main/tests/baselines/reference/config/matchFi...
# 1313937  'main/tests/baselines/reference/config/matchFi...
# 1313938  'main/tests/baselines/reference/config/matchFi...
# 1313939  'main/tests/baselines/reference/config/matchFi...
# 1313940  'main/tests/baselines/reference/config/matchFi...
# 1313941  'main/tests/baselines/reference/config/matchFi...
# 1313942  'main/tests/baselines/reference/config/matchFi...
# 1313943  'main/tests/baselines/reference/config/matchFi...
# 1313944  'main/tests/baselines/reference/config/matchFi...
# 1313945  'main/tests/baselines/reference/config/matchFi...
# 1313946  'main/tests/baselines/reference/config/matchFi...
# 1313947  'main/tests/baselines/reference/config/matchFi...
# 1585162  'main/OpenEmu.xcworkspace/xcshareddata/xcschem...
# 1585621  'main/OpenEmu/OpenEmu.xcodeproj/xcshareddata/x...
# 1766526           'main/test/rdoc/MarkdownTest_1.0.3/Links
# 1766527           'main/test/rdoc/MarkdownTest_1.0.3/Links
# 1766528           'main/test/rdoc/MarkdownTest_1.0.3/Links
# 2233094                                  'main/TODO/Of SVG
#
#                                                   fileSize  \
# 190650   non-trivial project - query test-0-3893ec7a860...
# 190651   non-trivial project - query test-0-eabbebd5c1d...
# 527276                                           Debugging
# 527277                                           Debugging
# 1302123                      Frank Seide August 2015.pptx'
# 1306193                        no leading whitespace.json'
# 1313898       then in alphabetical order with json api.js'
# 1313899  then in alphabetical order with jsonSourceFile...
# 1313936                    allowJs=false with json api.js'
# 1313937          allowJs=false with jsonSourceFile api.js'
# 1313938                     allowJs=true with json api.js'
# 1313939           allowJs=true with jsonSourceFile api.js'
# 1313940                    allowJs=false with json api.js'
# 1313941          allowJs=false with jsonSourceFile api.js'
# 1313942                     allowJs=true with json api.js'
# 1313943           allowJs=true with jsonSourceFile api.js'
# 1313944                    allowJs=false with json api.js'
# 1313945          allowJs=false with jsonSourceFile api.js'
# 1313946                     allowJs=true with json api.js'
# 1313947           allowJs=true with jsonSourceFile api.js'
# 1585162                                   Alpha).xcscheme'
# 1585621                                   Alpha).xcscheme'
# 1766526                                 inline style.text'
# 1766527                              reference style.text'
# 1766528                          shortcut references.text'
# 2233094                             Minification and Gzip'
#
#                                 idk   test
# 190650                         1954   None
# 190651                         1954   None
# 527276      and Testing on Unix.md'   5804
# 527277   and Testing on Windows.md'  15583
# 1302123                       54468   None
# 1306193                        1933   None
# 1313898                        1354   None
# 1313899                        1326   None
# 1313936                         854   None
# 1313937                         826   None
# 1313938                         890   None
# 1313939                         862   None
# 1313940                         916   None
# 1313941                         888   None
# 1313942                         952   None
# 1313943                         924   None
# 1313944                         924   None
# 1313945                         896   None
# 1313946                         960   None
# 1313947                         932   None
# 1585162                       26642   None
# 1585621                        6247   None
# 1766526                         231   None
# 1766527                         791   None
# 1766528                         236   None
# 2233094                       12669   None

# %%
not_null_rows = df[df['test'].notna()]

# Display the DataFrame with non-null rows
print(not_null_rows)
# Out:
#          owner    repo                                          name-size  \
# 527276  dotnet  roslyn  ('main/docs/contributing/Building, Debugging, ...
# 527277  dotnet  roslyn  ('main/docs/contributing/Building, Debugging, ...
#
#                                 filePath   fileSize  \
# 527276  'main/docs/contributing/Building  Debugging
# 527277  'main/docs/contributing/Building  Debugging
#
#                                idk   test
# 527276     and Testing on Unix.md'   5804
# 527277  and Testing on Windows.md'  15583

# %%
#find all the values in "idk" and replace with file size 
def replace_with_idk_value(df, row_indices, target_column):
    for row_index in row_indices:
        if pd.notna(df.loc[row_index, 'idk']):
            df.loc[row_index, target_column] = df.loc[row_index, 'idk']


not_null_rows = df[df['idk'].notna()]
row_numbers = not_null_rows.index.tolist()
replace_with_idk_value(df, row_numbers, 'fileSize')

# %%
#find all the values in "idk" and replace with file size 
def replace_with_idk_value(df, row_indices, target_column):
    for row_index in row_indices:
        if pd.notna(df.loc[row_index, 'test']):
            df.loc[row_index, target_column] = df.loc[row_index, 'test']


not_null_rows = df[df['test'].notna()]
row_numbers = not_null_rows.index.tolist()
replace_with_idk_value(df, row_numbers, 'fileSize')

# %%
df.isnull().sum()
# Out:
# owner              0
# repo              10
# name-size         10
# filePath          10
# fileSize          10
# idk          2258497
# test         2258521
# dtype: int64

# %%
df= df.drop(columns=['name-size','idk','test'])
df = df.dropna()
df['fileSize'] = df['fileSize'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258513 entries, 0 to 2258522
# Data columns (total 4 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   owner     object
#  1   repo      object
#  2   filePath  object
#  3   fileSize  int32
# dtypes: int32(1), object(3)
# memory usage: 77.5+ MB

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#   owner           repo                                          filePath  \
# 0  0xAX  linux-insides       'main/.github/ISSUE_TEMPLATE/bug_report.md'
# 1  0xAX  linux-insides  'main/.github/ISSUE_TEMPLATE/feature_request.md'
# 2  0xAX  linux-insides                                 'main/.gitignore'
# 3  0xAX  linux-insides                    'main/Assets/linux-kernel.png'
# 4  0xAX  linux-insides                          'main/Booting/README.md'
#
#    fileSize
# 0       565
# 1       638
# 2        12
# 3     31671
# 4      1158

# %%
df.count()
# Out:
# owner       2258513
# repo        2258513
# filePath    2258513
# fileSize    2258513
# dtype: int64

# %%
sns.set(style="whitegrid")

deep_palette = sns.color_palette("muted")

plt.figure(figsize=(10, 6))
sns.histplot(df, bins=20, color=deep_palette[0], edgecolor='black')

# Set the title and labels
plt.title('File Size Distribution', fontsize=16)
plt.xlabel('File Size (MB)', fontsize=14)
plt.ylabel('Number of Files', fontsize=14)

# Scale axes
plt.xscale('log')
plt.yscale('log')

# Add gridlines and legend
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend(['File Size Distribution'], fontsize=12)

plt.show()

# %%
column_description = df['fileSize'].describe()

print(column_description)
# Out:
# count    2.258513e+06
# mean     1.296818e+04
# std      2.407529e+05
# min      0.000000e+00
# 25%      3.390000e+02
# 50%      1.163000e+03
# 75%      3.839000e+03
# max      7.950287e+07
# Name: fileSize, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='fileSize', data=df)
plt.title('File Size Distribution (Violin Plot)')
plt.xlabel('File Size (bytes)')
plt.ylabel('Logarithmic Scale')
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the sum of file sizes for each repository
repo_file_size_sum = df.groupby('repo')['fileSize'].sum()

# Get the top 7 repositories by file size sum
top_repos = repo_file_size_sum.nlargest(7).index
filtered_df = df[df['repo'].isin(top_repos)]

plt.figure(figsize=(12, 8))
sns.boxplot(x='repo', y='fileSize', data=filtered_df, order=top_repos)
plt.title('Distribution of File Sizes by Repository (Top 7 by File Size Sum)')
plt.xlabel('Repository')
plt.ylabel('File Size (log scale)')
plt.yscale('log')

plt.show()

# %%
df
# Out:
#          owner           repo  \
# 0         0xAX  linux-insides
# 1         0xAX  linux-insides
# 2         0xAX  linux-insides
# 3         0xAX  linux-insides
# 4         0xAX  linux-insides
# ...        ...            ...
# 2258518  zxing          zxing
# 2258519  zxing          zxing
# 2258520  zxing          zxing
# 2258521  zxing          zxing
# 2258522  zxing          zxing
#
#                                                   filePath  fileSize
# 0              'main/.github/ISSUE_TEMPLATE/bug_report.md'       565
# 1         'main/.github/ISSUE_TEMPLATE/feature_request.md'       638
# 2                                        'main/.gitignore'        12
# 3                           'main/Assets/linux-kernel.png'     31671
# 4                                 'main/Booting/README.md'      1158
# ...                                                    ...       ...
# 2258518  'main/zxingorg/src/test/java/com/google/zxing/...      1112
# 2258519  'main/zxingorg/src/test/java/com/google/zxing/...      1027
# 2258520  'main/zxingorg/src/test/java/com/google/zxing/...      1248
# 2258521  'main/zxingorg/src/test/java/com/google/zxing/...      1995
# 2258522  'main/zxingorg/src/test/java/com/google/zxing/...      1675
#
# [2258513 rows x 4 columns]

# %%
top_message = df['repo'].value_counts().head(10)
top_message
# Out:
# repo
# servo              127066
# test-repo          100005
# hhvm                89616
# linux               82439
# kotlin              82251
# DefinitelyTyped     73368
# TypeScript          70224
# kibana              70049
# gitlabhq            52166
# mongo               46364
# Name: count, dtype: int64

# %%
# Remove duplicates based on the 'repo' column to ensure unique repository selection
unique_repos = df.drop_duplicates(subset=['repo'])

# sample a random repository from the unique list
random_repo = unique_repos.sample(n=1)

print(random_repo)
# Out:
#           owner                  repo  \
# 1209199  jondot  awesome-react-native
#
#                                         filePath  fileSize  \
# 1209199  'main/.github/PULL_REQUEST_TEMPLATE.md'       107
#
#                  fileCategory fileType
# 1209199  GitHub Configuration       md

# %%
import pandas as pd

# Group by 'repo' and sum the 'fileSize' for each repository
repo_sizes = df.groupby('repo')['fileSize'].sum()

# repository with the largest total file size
largest_repo = repo_sizes.idxmax()
largest_repo_size = repo_sizes.max()

print(f"The largest repository is {largest_repo} with a total file size of {largest_repo_size} bytes.")
# Out:
# The largest repository is fonts with a total file size of 1995941979 bytes.

# %% [markdown]
# ## look at the file exntension distribution of a randomly selected repo

# %%
# Filter the DataFrame for the specific owner and repo
df = df[(df['owner'] == 'bitcoin') & (df['repo'] == 'bitcoin')]

# %%
import matplotlib.pyplot as plt
import pandas as pd

#filtered_df = df[df['owner'] != 'Alexander-MacDonald']
top_owners = filtered_df['owner'].value_counts().nlargest(10)

# Create a pie chart using matplotlib for the top 10 owners, excluding "test"
plt.figure(figsize=(8, 8))
plt.pie(top_owners, labels=top_owners.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 10 Owners Distribution Based on File Count')
plt.show()

# %%
# Categorize files
def categorize_file(file_path):
    if '/tests/' in file_path:
        return 'Test'
    elif '/docs/' in file_path or '/documentation/' in file_path:
        return 'Documentation'
    elif '/.github/' in file_path:
        return 'GitHub Configuration'
    else:
        return 'Code'

# Apply categorization
df['fileCategory'] = df['filePath'].apply(categorize_file)

# Calculate the ratio of code to documentation
code_count = df[df['fileCategory'] == 'Code'].shape[0]
documentation_count = df[df['fileCategory'] == 'Documentation'].shape[0]

ratio_code_to_documentation = code_count / documentation_count if documentation_count != 0 else 0

print(f"Number of code files: {code_count}")
print(f"Number of documentation files: {documentation_count}")
print(f"Ratio of code to documentation: {ratio_code_to_documentation:.2f}")
# Out:
# Number of code files: 2630
# Number of documentation files: 0
# Ratio of code to documentation: 0.00

# %%
import os
import pandas as pd


# Function to extract the file extension and clean it
def get_file_extension(file_path):
    # Extract the extension
    extension = os.path.splitext(file_path)[1]
    # Remove the leading dot and any single quotes
    cleaned_extension = extension.replace('.', '').replace("'", "")
    return cleaned_extension

# Apply the function to the 'filePath' column to get clean extensions without leading dot and quotes
df['fileType'] = df['filePath'].apply(get_file_extension)

file_type_counts = df['fileType'].value_counts()



# Convert the file_type_counts to a string with each line containing the extension and count
file_types_str = '\n'.join([f"{ext}: {count}" for ext, count in file_type_counts.items()])

# Define the path for the output text file
output_file_path = 'file_types_counts.txt'  # Change this to your preferred path

with open(output_file_path, 'w') as file:
    file.write(file_types_str)

# %%
df.head()
# Out:
#           owner     repo                                  filePath  fileSize  \
# 284402  bitcoin  bitcoin                        'main/.cirrus.yml'      7261
# 284403  bitcoin  bitcoin                      'main/.editorconfig'       416
# 284404  bitcoin  bitcoin                     'main/.gitattributes'        35
# 284405  bitcoin  bitcoin     'main/.github/ISSUE_TEMPLATE/bug.yml'      3123
# 284406  bitcoin  bitcoin  'main/.github/ISSUE_TEMPLATE/config.yml'       281
#
#                 fileCategory fileType
# 284402                  Code      yml
# 284403                  Code
# 284404                  Code
# 284405  GitHub Configuration      yml
# 284406  GitHub Configuration      yml

# %%
# Define the categorization function based on fileType
def categorize_file_by_type(file_type, code_exts, doc_exts):
    # Directly categorize based on the fileType
    if file_type in code_exts:
        return 'Code'
    elif file_type in doc_exts:
        return 'Documentation'
    else:
        return 'Other'

# Define the sets of file extensions
code_extensions = {
    'js', 'java', 'c', 'cpp', 'cs', 'py', 'go', 'rb', 'php', 'ts', 'swift', 'kt', 'rs',
    'h', 'hpp', 'cxx', 'cc', 'm', 'scala', 'sh', 'bash', 'sql', 'pl', 'pm', 't', 'tsx',
    'jsx', 'lua', 'groovy', 'gd', 'tcl', 'vbs', 's', 'r', 'd', 'mdx', 'swift', 'kts',
    'ino', 'cls', 'pas', 'asm', 's', 'v', 'vhdl', 'sv', 'svh', 'f', 'f90', 'f95', 'for',
    'ftn', 'sas', 'jl', 'mat', 'mex', 'mexn', 'mexrs6', 'mn', 'mum', 'nb', 'nbp', 'p', 
    'mlx', 'r2015bc', 'r2015a', 'r2015b', 'r2016a', 'r2016b', 'r2017a', 'r2017b', 'r2018a',
    'r2018b', 'r2019a', 'r2019b', 'r2020a', 'r2020b', 'r2021a', 'r2021b', 'xmcd', 'xvc', 
    'mlapp', 'plsql', 'yaml', 'yml', 'json', 'xml', 'gradle', 'html', 'css', 'scss', 'less', 'md',
    'sass', 'ejs', 'jsp', 'dart', 'swiftui', 'toml', 'ini', 'cfg', 'conf',
    'ps1', 'bat', 'zsh', 'fish', 'ipynb', 'rmd', 'gradle', 'xml', 'yaml', 'json', 'o', 'obj', 'a', 'lib', 'so', 'dll', 'dylib', 'awk', 'sed', 'tf', 'dockerfile', 'db', 'sqlite', 'mdb', 'tf', 'hcl', 'dockerfile', 'compose', 'vue', 'jsx', 'tsx',
    'erb', 'pug', 'twig', 'unity', 'unoproj', 'godot', 'data', 'model', 'keras'
    'sol', 'wasm', 'wasm', 'asp', 'php5', 'php7', 'phtml', 'awk', 'perl', 'pyc', 'rbw',
    'o', 'a', 'lib', 'dll', 'so', 'dylib', 'k8s', 'helm', 'chart', 'vagrant',
    'ansible', 'puppet', 'chef', 'csv', 'parquet', 'orc', 'avro', 'pickle',
    'npz', 'npy', 'git', 'gitignore', 'gitconfig', 'gitattributes', 'svn',
    'npm', 'yarn', 'makefile', 'cmake', 'gradlew', 'pom.xml', 'gemspec', 'nuspec',
    'spec', 'test', 'tests', 'testing', 'benchmark', 'less', 'sass', 'styl', 'awk', 'sed', 'ksh', 'env', 'properties', 'tfstate', 'tfvars',
    'gitlab-ci.yml', 'travis.yml', 'npmrc', 'yarnrc', 'gemspec', 'makefile', 'cmake', 'gradlew',
    'lua', 'perl', 'prl', 'r', 'rscript', 'vba', 'vb', 'pas', 'erl', 'ex', 'exs', 'scala', 'groovy'
}

doc_extensions = {
    'png','md', 'txt', 'rst', 'doc', 'docx', 'pdf', 'odt', 'rtf', 'tex', 'latex', 'ltx', 'wpd', 'epub', 'chm', 'markdown',
    'svg', 'gif', 'jpeg', 'jpg','asciidoc', 'dita', 'docm', 'bmp', 'tiff', 'mp4', 'avi', 'mov', 'ppt', 'pptx', 'uml', 'dia', 
    'drawio', 'asciidoc', 'nroff', 'epub', 'mobi', 'ibooks', 'psd', 'ai', 'indd', 'sketch', 'xd',
    'mp4', 'avi', 'mov', 'flv', 'mkv', 'mp3', 'wav', 'aac', 'ogg', 'flac',
    'xls', 'xlsx', 'ods', 'ppt', 'pptx', 'odp', 'vsdx', 'bpmn', 'mobi', 'epub', 'ibooks', 'dita', 'ditamap', 'wikitext', 'ai', 'psd', 'indd', 'sketch', 'fig',
    'stl', 'obj', 'dwg', 'dxf'
}



# Apply the categorization to the DataFrame based on the fileType column
df['fileCategory'] = df['fileType'].apply(lambda x: categorize_file_by_type(x, code_extensions, doc_extensions))

# %%
# Get the counts of each file category
category_counts = df['fileCategory'].value_counts()

# Extract the counts for code and documentation
code_count = category_counts.get('Code', 0)
documentation_count = category_counts.get('Documentation', 0)

# Calculate the ratio of code to documentation
ratio_code_to_documentation = code_count / documentation_count if documentation_count != 0 else 0

print(f"Number of code files: {code_count}")
print(f"Number of documentation files: {documentation_count}")
print(f"Ratio of code to documentation: {ratio_code_to_documentation:.2f}")
# Out:
# Number of code files: 2171
# Number of documentation files: 131
# Ratio of code to documentation: 16.57

# %%
import seaborn as sns
import pandas as pd

# Assuming the content of the file_types_counts.txt is stored in a DataFrame 'file_types_df'
# We will read the content into a DataFrame, assuming the structure is similar to what was provided
file_types_df = pd.read_csv('file_types_counts.txt', sep=':', names=['fileType', 'count'])

# Clean up the file types by removing unwanted characters and sorting
file_types_df['fileType'] = file_types_df['fileType'].str.strip().str.replace("'", "").str.replace('"', '')
file_types_df = file_types_df.dropna()
file_types_df = file_types_df[file_types_df['fileType'] != '']  # Remove any empty file types if present
file_types_df = file_types_df.sort_values(by='count', ascending=False)  # Sort the data for better visualization

# Taking only the top 20 file types to keep the plot readable
top_file_types_df = file_types_df.head(10)

plt.figure(figsize=(14, 7))
sns.barplot(data=top_file_types_df, x='fileType', y='count', palette='deep')

plt.title('Top 10 File Types Distribution - Bitcoin/Bitcoin')
plt.xlabel('File Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to ensure everything fits without overlapping
plt.show()

# %% [markdown]
# ##### idenitfy the "other' files

# %%
# Define the categorization function based on file path
def categorize_file(file_path):
    if '/tests/' in file_path:
        return 'Test'
    elif '/docs/' in file_path or '/documentation/' in file_path:
        return 'Documentation'
    elif '/.github/' in file_path:
        return 'GitHub Configuration'
    else:
        return 'Code'

# Apply the categorization function only to rows with 'Other' in fileCategory
df.loc[df['fileCategory'] == 'Other', 'fileCategory'] = df[df['fileCategory'] == 'Other']['filePath'].apply(categorize_file)

# Recalculate the counts for code and documentation categories
code_count = df[df['fileCategory'] == 'Code'].shape[0]
documentation_count = df[df['fileCategory'] == 'Documentation'].shape[0]

# Recalculate the ratio of code to documentation
ratio_code_to_documentation = code_count / documentation_count if documentation_count != 0 else 0

print(f"Number of code files: {code_count}")
print(f"Number of documentation files: {documentation_count}")
print(f"Ratio of code to documentation: {ratio_code_to_documentation:.2f}")
# Out:
# Number of code files: 2510
# Number of documentation files: 131
# Ratio of code to documentation: 19.16

# %%
# Let's plot the filtered categories again with different colors for each bar
filtered_category_counts = category_counts[category_counts.index != 'GitHub Configuration']
# Assigning a unique color to each category
colors = ['skyblue', 'lightgreen', 'orange']  # We have three colors for three categories

# If there are more categories, we can generate more colors or use a colormap
if len(filtered_category_counts) > len(colors):
    cmap = plt.get_cmap('tab10')  
    colors = [cmap(i) for i in range(len(filtered_category_counts))]

# Plotting the bar chart with different colors for each bar
filtered_category_counts.plot(kind='bar', color=colors)

plt.title('File Category Distribution - Bitcoin/Bitcoin')
plt.xlabel('File Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()   
plt.show()
